# %%
def route_query(query: str) -> str:
    """Route a customer query to the correct support agent."""
    q = query.lower()
    if q in ("cancel","refund"):
        return "human _agent"
    elif q in ("track","where"):
        return "order_agent"
    elif q in ("return","exchange"):
        return "returns_agent"
    elif q in ("price","discount"):
        return "promotions_agent"
    elif q in ("product","spec"):
        return "catalog_agent"
    else:
        return "general_agent"

# %%
def route_query(query: str) -> str:
    """Route a customer query to the correct support agent."""
    q = query.lower()
    if   "cancel" in q or "refund"   in q: return "human_agent"
    elif "track"  in q or "where"    in q: return "order_agent"
    elif "return" in q or "exchange" in q: return "returns_agent"
    elif "price"  in q or "discount" in q: return "promotions_agent"
    elif "product" in q or "spec"    in q: return "catalog_agent"
    else:                                   return "general_agent"

# %%
queries = ["where is my order?", "I want a refund", "Do you have discount"]

# %%
for q in queries:
    print(q)
# Out:
# where is my order?
# I want a refund
# Do you have discount

# %%
for q in queries:
    print(f" '{q}'  → {route_query(q)}")
# Out:
#  'where is my order?'  → order_agent
#  'I want a refund'  → human_agent
#  'Do you have discount'  → promotions_agent

# %%
for q in queries:
    print(f"  '{q}'  →  {route_query(q)}")
# Out:
#   'where is my order?'  →  order_agent
#   'I want a refund'  →  human_agent
#   'Do you have discount'  →  promotions_agent
